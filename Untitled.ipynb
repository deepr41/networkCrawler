# %%
import pandas as pd

# %%
pd.read_csv('finale.csv',error_bad_lines=False)
# Out:
# b'Skipping line 89711: expected 9 fields, saw 10\nSkipping line 110055: expected 9 fields, saw 10\n'
# b'Skipping line 177933: expected 9 fields, saw 10\nSkipping line 179526: expected 9 fields, saw 10\n'
# b'Skipping line 200983: expected 9 fields, saw 10\nSkipping line 210669: expected 9 fields, saw 10\nSkipping line 215653: expected 9 fields, saw 10\nSkipping line 258120: expected 9 fields, saw 10\n'
# b'Skipping line 292870: expected 9 fields, saw 10\n'
#          10395                   nazwa.pl  \
# 0        10411        thepiratefilmes.biz
# 1        10409                 vsetop.org
# 2        10406          bubbletorrent.com
# 3        10404                   udel.edu
# 4        10410  networksolutionsemail.com
# 5        10399                  orange.pl
# 6        10400              downmagaz.com
# 7        10403                      te.eg
# 8        10416                 bertina.us
# 9        10417           gameinformer.com
# 10       10414               kankanwu.com
# ...
